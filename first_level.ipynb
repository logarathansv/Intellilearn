# %%
import pandas as pd
import json

# Read the entire JSON file and loading all JSON objects
with open("./train.json", 'r') as json_file:
    json_data = json_file.read()

# Split the file content into individual JSON objects
json_objects = json_data.strip().split('\n')

# Convert JSON objects to DataFrames and store them in a list
dataframes = []
for json_obj in json_objects:
    try:
        json_dict = json.loads(json_obj)
        df = pd.DataFrame([json_dict])
        dataframes.append(df)
    except json.JSONDecodeError:
        print(f"Skipping invalid JSON: {json_obj}")

# Concatenate all DataFrames into one
final_dataframe = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a CSV file
final_dataframe.to_csv('output.csv', index=False)

print("Combined DataFrame saved as output.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import json
#       4 # Read the entire JSON file and loading all JSON objects
# ----> 5 with open("./train.json", 'r') as json_file:
#       6     json_data = json_file.read()
#       8 # Split the file content into individual JSON objects
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './train.json'

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
df=pd.read_csv("output.csv")

# %%
df.shape
# Out:
# (182822, 11)

# %%
df.head()
# Out:
#                                             question  \
# 0  Chronic urethral obstruction due to benign pri...
# 1  Which vitamin is supplied from only animal sou...
# 2  All of the following are surgical options for ...
# 3  Following endaerectomy on the right common car...
# 4   Growth hormone has its effect on growth through?
#
#                                                  exp  cop  \
# 0  Chronic urethral obstruction because of urinar...    3
# 1  Ans. (c) Vitamin B12 Ref: Harrison's 19th ed. ...    3
# 2  Ans. is 'd' i.e., Roux en Y Duodenal Bypass Ba...    4
# 3  The central aery of the retina is a branch of ...    1
# 4  Ans. is 'b' i.e., IGI-1GH has two major functi...    2
#
#                           opa                        opb              opc  \
# 0                 Hyperplasia                  Hyperophy          Atrophy
# 1                   Vitamin C                 Vitamin B7      Vitamin B12
# ...

# %%
df=df.drop(["choice_type","subject_name","topic_name","exp"],axis=1)
df.head()
# Out:
#                                             question  cop  \
# 0  Chronic urethral obstruction due to benign pri...    3
# 1  Which vitamin is supplied from only animal sou...    3
# 2  All of the following are surgical options for ...    4
# 3  Following endaerectomy on the right common car...    1
# 4   Growth hormone has its effect on growth through?    2
#
#                           opa                        opb              opc  \
# 0                 Hyperplasia                  Hyperophy          Atrophy
# 1                   Vitamin C                 Vitamin B7      Vitamin B12
# 2  Adjustable gastric banding  Biliopancreatic diversion  Duodenal Switch
# 3  Central aery of the retina          Infraorbital aery    Lacrimal aery
# 4                    Directly                      IG1-1        Thyroxine
#
#                           opd                                    id
# 0                    Dyplasia  e9ad821a-c438-4965-9f77-760819dfa155
# ...

# %%
df.isnull().sum()
# Out:
# question       0
# cop            0
# opa            5
# opb            2
# opc           23
# opd         2727
# id             0
# dtype: int64

# %%
df.shape
# Out:
# (182822, 7)

# %%
df=df.dropna(subset="opa")
df=df.dropna(subset="opb")
df=df.dropna(subset="opc")
df=df.dropna(subset="opd")

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (180066, 7)
# question    0
# cop         0
# opa         0
# opb         0
# opc         0
# opd         0
# id          0
# dtype: int64

# %%
df.head()
# Out:
#                                             question  cop  \
# 0  Chronic urethral obstruction due to benign pri...    3
# 1  Which vitamin is supplied from only animal sou...    3
# 2  All of the following are surgical options for ...    4
# 3  Following endaerectomy on the right common car...    1
# 4   Growth hormone has its effect on growth through?    2
#
#                           opa                        opb              opc  \
# 0                 Hyperplasia                  Hyperophy          Atrophy
# 1                   Vitamin C                 Vitamin B7      Vitamin B12
# 2  Adjustable gastric banding  Biliopancreatic diversion  Duodenal Switch
# 3  Central aery of the retina          Infraorbital aery    Lacrimal aery
# 4                    Directly                      IG1-1        Thyroxine
#
#                           opd                                    id
# 0                    Dyplasia  e9ad821a-c438-4965-9f77-760819dfa155
# ...

# %%
random_diff=np.random.randint(0,3,size=len(df))
df["Difficulty"]=random_diff
df.head()
# Out:
#                                             question  cop  \
# 0  Chronic urethral obstruction due to benign pri...    3
# 1  Which vitamin is supplied from only animal sou...    3
# 2  All of the following are surgical options for ...    4
# 3  Following endaerectomy on the right common car...    1
# 4   Growth hormone has its effect on growth through?    2
#
#                           opa                        opb              opc  \
# 0                 Hyperplasia                  Hyperophy          Atrophy
# 1                   Vitamin C                 Vitamin B7      Vitamin B12
# 2  Adjustable gastric banding  Biliopancreatic diversion  Duodenal Switch
# 3  Central aery of the retina          Infraorbital aery    Lacrimal aery
# 4                    Directly                      IG1-1        Thyroxine
#
#                           opd                                    id  \
# 0                    Dyplasia  e9ad821a-c438-4965-9f77-760819dfa155
# ...

# %%
df.to_csv('Questions.csv', index=False)
